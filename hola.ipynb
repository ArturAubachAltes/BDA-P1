# %% [markdown]
# !pip install datadotworld[pandas]

# %% [markdown]
# # DATA COLECTORS

# %% [markdown]
# ## Data world (sales)

# %%
# !pip install datadotworld[pandas]
# Out:
# ...
#      ---------------------------------------- 0.0/40.2 kB ? eta -:--:--
#      ----------------------------- -------- 30.7/40.2 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 40.2/40.2 kB 636.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/47.9 kB ? eta -:--:--
#      ---------------------------------------- 47.9/47.9 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/48.9 kB ? eta -:--:--
#      ---------------------------------------- 48.9/48.9 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#      - -------------------------------------- 0.3/10.3 MB 9.9 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.0/10.3 MB 13.1 MB/s eta 0:00:01
#      ------ --------------------------------- 1.7/10.3 MB 15.0 MB/s eta 0:00:01
#      -------- ------------------------------- 2.3/10.3 MB 13.3 MB/s eta 0:00:01
# ...

# %%
import datadotworld as dw

# Reemplaza 'usuario/dataset' con el identificador apropiado de la base de datos que deseas descargar
dataset = dw.load_dataset('usuario/dataset', force_update=True)

# Acceso a un DataFrame específico dentro del conjunto de datos
df = dataset.dataframes['nombre_del_dataframe']

# Ahora puedes trabajar con 'df' como lo harías con cualquier otro DataFrame de pandas
# Out:
#   Cell In[10], line 7
#     token = 'eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50OmFyYXVhbCIsImlzcyI6ImFnZW50OmFyYXVhbDo6MWU2ZTVmYTItZTZkOC00NzQ5LTg3MzgtMzE5MDdiM2ZlZDdkIiwiaWF0IjoxNzEwNDk1Mjc0LCJyb2xlIjpbInVzZXJfYXBpX3JlYWQiLCJ1c2VyX2FwaV93cml0ZSJdLCJnZW5lcmFsLXB1cnBvc2UiOnRydWUsInNhbWwiOnt9fQ.MD_KoCzUNWcGvbTNdDF79uPq93Mpeo8gtyRWiV4UmgWmO71GNhoi1G66UnWycY_fBGtupGx1rrzzK7lFmOIqEQ''
#                                                                                                                                                                                                                                                                                                                                                                                 ^
# SyntaxError: unterminated string literal (detected at line 7)

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# La sintaxis del comando no es correcta.
# "cp" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# "chmod" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
import requests
from zipfile import ZipFile
from io import BytesIO
import os

# Sustituye 'your_token' con el token de acceso que copiaste
token = 'eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50OmFyYXVhbCIsImlzcyI6ImFnZW50OmFyYXVhbDo6MWU2ZTVmYTItZTZkOC00NzQ5LTg3MzgtMzE5MDdiM2ZlZDdkIiwiaWF0IjoxNzEwNDk1Mjc0LCJyb2xlIjpbInVzZXJfYXBpX3JlYWQiLCJ1c2VyX2FwaV93cml0ZSJdLCJnZW5lcmFsLXB1cnBvc2UiOnRydWUsInNhbWwiOnt9fQ.MD_KoCzUNWcGvbTNdDF79uPq93Mpeo8gtyRWiV4UmgWmO71GNhoi1G66UnWycY_fBGtupGx1rrzzK7lFmOIqEQ'

# Estos son el dueño y el identificador del conjunto de datos en data.world
owner = 'ricjaramillo'
dataset_id = 'sales'

url = f'https://api.data.world/v0/download/{owner}/{dataset_id}'

headers = {
    'Authorization': f'Bearer {token}',
    'Accept': 'application/zip'
}

response = requests.get(url, headers=headers)

# Asegúrate de que la petición fue exitosa
if response.status_code == 200:
    # Usa BytesIO para manejar el contenido de la respuesta como un archivo en memoria
    zipfile = ZipFile(BytesIO(response.content))

    # Definir el path de la carpeta de destino
    destination_folder = 'DADES/data_world'
    # Crea la carpeta si no existe
    os.makedirs(destination_folder, exist_ok=True)

    # Extrae los archivos individualmente
    for file_info in zipfile.infolist():
        extracted_path = os.path.join(destination_folder, file_info.filename)

        # Comprobamos si es directorio (termina con '/')
        if file_info.filename.endswith('/'):
            os.makedirs(extracted_path, exist_ok=True)
        else:
            with open(extracted_path, 'wb') as file:
                # Escribimos el contenido del archivo en la nueva ruta
                file.write(zipfile.read(file_info.filename))

    print(f"Los archivos han sido extraídos en la carpeta: {
          destination_folder}")
else:
    print("Error en la descarga:", response.status_code)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 40
#      38         os.makedirs(extracted_path, exist_ok=True)
#      39     else:
# ---> 40         with open(extracted_path, 'wb') as file:
#      41             # Escribimos el contenido del archivo en la nueva ruta
#      42             file.write(zipfile.read(file_info.filename))
#      44 print(f"Los archivos han sido extraídos en la carpeta: {
#      45       destination_folder}")
#
# File c:\Users\artur\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
# ...

# %%
import requests

# Sustituye 'your_token' con el token de acceso que copiaste
token = 'eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50OmFyYXVhbCIsImlzcyI6ImFnZW50OmFyYXVhbDo6MWU2ZTVmYTItZTZkOC00NzQ5LTg3MzgtMzE5MDdiM2ZlZDdkIiwiaWF0IjoxNzEwNDk1Mjc0LCJyb2xlIjpbInVzZXJfYXBpX3JlYWQiLCJ1c2VyX2FwaV93cml0ZSJdLCJnZW5lcmFsLXB1cnBvc2UiOnRydWUsInNhbWwiOnt9fQ.MD_KoCzUNWcGvbTNdDF79uPq93Mpeo8gtyRWiV4UmgWmO71GNhoi1G66UnWycY_fBGtupGx1rrzzK7lFmOIqEQ'

# Estos son el dueño y el identificador del conjunto de datos en data.world
owner = 'ricjaramillo'
dataset_id = 'sales'

url = f'https://api.data.world/v0/download/{owner}/{dataset_id}'

headers = {
    'Authorization': f'Bearer {token}',
    'Accept': 'application/zip'
}

response = requests.get(url, headers=headers)

# Asegúrate de que la petición fue exitosa
if response.status_code == 200:
    filename = f'{dataset_id}.zip'
    with open(filename, 'wb') as f:
        f.write(response.content)
    print(f"Descarga completa: {filename}")
else:
    print("Error en la descarga:", response.status_code)
# Out:
# Descarga completa: sales.zip
